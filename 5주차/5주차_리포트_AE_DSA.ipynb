# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### 데이터 불러오기

# %%
df = pd.read_csv('data/DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# ...

# %%
df.shape
# Out:
# (9120, 272)

# %% [markdown]
# ## 1. DSA데이터에서 sitting(normal) jumping(abnormal)만 남김

# %%
data = df[(df['activity']=='sitting') | (df['activity']=='jumping')]
data
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 8635     9.298029     32.4980     -6.0782  134.634624   11.603216
# 8636     8.738784     34.0480     -6.7822  145.225186   12.050941
# 8637     9.404261     34.8670     -5.3331  130.142955   11.408022
# 8638     9.139112     32.5060     -6.8835  135.812815   11.653876
# 8639     8.868404     30.9070     -6.7151  128.743919   11.346538
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150     1.18320     0.99744    0.002208  ...
# ...

# %% [markdown]
# ### 인덱스 초기화, people 열 삭제

# %%
data = data.reset_index(drop=True)
data = data.drop('people', axis=1)
data
# Out:
#      T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0       7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1       7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2       7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3       7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4       7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
# ..           ...         ...         ...         ...         ...          ...
# 955     9.298029     32.4980     -6.0782  134.634624   11.603216     0.570723
# 956     8.738784     34.0480     -6.7822  145.225186   12.050941     0.760224
# 957     9.404261     34.8670     -5.3331  130.142955   11.408022     0.560963
# 958     9.139112     32.5060     -6.8835  135.812815   11.653876     0.589304
# 959     8.868404     30.9070     -6.7151  128.743919   11.346538     0.585457
#
# ...

# %%
data.shape
# Out:
# (960, 271)

# %%
data.isnull().values.any()
# Out:
# False

# %%
data['activity'].value_counts()
# Out:
# activity
# sitting    480
# jumping    480
# Name: count, dtype: int64

# %% [markdown]
# ### label 칼럼 숫자로 변환

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 'label' 컬럼을 숫자로 변환
data['activity'] = label_encoder.fit_transform(data['activity'])

# %%
data['activity'].value_counts()
# Out:
# activity
# 1    480
# 0    480
# Name: count, dtype: int64

# %%
RANDOM_SEED = 42

# %% [markdown]
# ### train, valid, test 로 데이터 분할

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)

X_train_new, X_valid = train_test_split(X_train, test_size=0.2, random_state=RANDOM_SEED)

# 4. training/valid에서 jumping 데이터를 삭제 ( sitting를 정상데이터로 사용)
X_train_new = X_train_new[X_train_new.activity==1]
X_train_sitting = X_train_new.drop(['activity'], axis=1)

X_valid = X_valid[X_valid.activity==1]
X_valid_sitting = X_valid.drop(['activity'], axis=1)

X_train_sitting = X_train_sitting.values
X_valid_sitting = X_valid_sitting.values

# %% [markdown]
# ### 오토인코더 모델 정의

# %%
# 오토인코더 모델

input_dim = X_train_sitting.shape[1]

input_layer = Input(shape=(input_dim,))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
encoded = Dense(16, activation='relu')(encoded)
decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %% [markdown]
# ### 5. AE로 valid를 목표로 training을 학습

# %%
# 3. 모델 학습
# 훈련데이터의 0.1 을 validation data로 사용
history = autoencoder.fit(X_train_sitting, X_train_sitting, 
                          epochs=50, 
                          batch_size=256, 
                          shuffle=True, 
                          validation_data = (X_valid_sitting, X_valid_sitting))
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 5.5246 - val_loss: 5.6246
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 5.4904 - val_loss: 5.5811
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.4503 - val_loss: 5.5207
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.3876 - val_loss: 5.4420
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.3038 - val_loss: 5.3485
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 5.2092 - val_loss: 5.2451
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 5.1063 - val_loss: 5.1400
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 5.0022 - val_loss: 5.0423
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.9080 - val_loss: 4.9600
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 4.8270 - val_loss: 4.8949
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 4.7630 - val_loss: 4.8449
# Epoch 12/50
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %% [markdown]
# ### 6. sitting에 학습된 모델을 가지고,
#
# AE에 넣어서 Reconstruction error(입력/출력차이)를 구함

# %%
y_test = X_test['activity']
X_test = X_test.drop(['activity'], axis=1)

X_test = X_test.values



# X_test 값을 넣어서 Reconstruction Error 값을 얻고,
# 실제 레이블인 y_test와 데이터프레임으로 구성
# Reconstruction Error + 실제 레이블의 형태가 됨

predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#        reconstruction_error  true_class
# count            192.000000  192.000000
# mean             292.165106    0.447917
# std              436.498780    0.498580
# min                4.405158    0.000000
# 25%                4.573473    0.000000
# 50%               70.826830    0.000000
# 75%              493.259323    1.000000
# max             2929.336778    1.000000

# %%
error_df.head()
# Out:
#      reconstruction_error  true_class
# 836            131.582391           0
# 477              4.800632           1
# 350              4.574117           1
# 893            878.173643           0
# 923            372.812408           0

# %% [markdown]
# ### 7. 적당한 threshold값으로 분류수행구함

# %%
# threshold 값을 조정하여 최선의 정확도를 얻음, 그래프로를 보고 결정

threshold = 30

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "sitting" if name == 1 else "jumping")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# ### 8. accuracy를 구함

# %%
LABELS = ['sitting', 'jumping']

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = [0 if e > threshold else 1 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

print(classification_report(error_df.true_class, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       106
#            1       1.00      1.00      1.00        86
#
#     accuracy                           1.00       192
#    macro avg       1.00      1.00      1.00       192
# weighted avg       1.00      1.00      1.00       192
